# %%
# %pylab inline
# %precision 6
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode, iplot
import plotly.plotly as py
init_notebook_mode(connected=True)
from importlib import reload
from rtree import index

import sys
sys.path.append('../')
import Merkle_3D_Rtree.spatiotemporal as sp
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/ildar/anaconda3/envs/ds/lib/python3.5/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.18.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# #### Notes
# - conda install -n ds basemap
# - conda install -n ds geopandas
# - conda isntall -n ds rtree

# %%
reload(sp)
data = sp.read_dataset_eartquakes()
# Out:
# /home/ildar/projects/pycharm/spatiotemporal_blocks/data
# 1974-02-24 23:30:25

# %%
data.describe()

# %% [markdown]
# ### 3D R-tree

# %%
reload(sp)
data = sp.read_semantic_dataset()

# %%
reload(sp)
idx3d = sp.Merkle3DRtree(data)
bounds = idx3d.describe()
idx3d.draw_cube(bounds)
# Out:
# Time elaspsed (s) 0.039685726165771484
# 0 -> (50) [124, 125, 145, 147, 163, 166, 168, 175, 207, 274, 311, 353, 363, 388, 410, 435, 439, 504, 509, 510, 511, 555, 562, 563, 564, 565, 566, 567, 568, 569, 570, 572, 574, 575, 577, 579, 582, 593, 595, 630, 631, 632, 641, 642, 644, 655, 656, 661, 667, 673]
# 		19.00 21.20 35.60 38.50 161210326 248140551
# 4 -> (50) [133, 164, 169, 171, 198, 210, 223, 243, 251, 256, 269, 283, 285, 294, 299, 300, 305, 319, 332, 359, 360, 365, 386, 394, 397, 398, 433, 444, 449, 451, 452, 453, 471, 472, 473, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492]
# 		19.10 21.25 38.70 41.00 169247356 231449361
# 3 -> (50) [1405, 1408, 1409, 1411, 1414, 1442, 1461, 1485, 1486, 1497, 1537, 1544, 1557, 1558, 1562, 1573, 1574, 1577, 1600, 1613, 1614, 1620, 1621, 1643, 1646, 1651, 1659, 1660, 1661, 1663, 1664, 1665, 1668, 1669, 1671, 1673, 1675, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1689, 1695]
# ...

# %%
tree = idx3d.get_tree()
tree
# Out:
# {0: {'bounds': (19.000000,
#    21.200000,
#    35.600000,
#    38.000000,
#    161210326.000000,
#    247537577.000000),
#   'items': [124,
#    125,
#    145,
#    147,
#    163,
#    166,
#    168,
#    175,
#    207,
#    274,
#    311,
#    353,
#    363,
#    388,
#    410,
#    435,
#    504,
#    509,
#    510,
#    562,
#    563,
#    564,
#    565,
#    566,
#    567,
#    569,
#    570,
#    574,
#    577,
#    579,
#    582,
#    593,
#    595,
#    630,
#    631,
#    632,
#    642,
#    655,
#    656,
#    667]},
#  2: {'bounds': (19.750000,
#    21.200000,
#    35.000000,
#    38.000000,
#    248140551.000000,
#    278334156.000000),
#   'items': [673,
#    686,
#    724,
#    736,
#    738,
#    739,
#    742,
#    961,
#    962,
#    977,
#    978,
#    979,
#    999,
#    1005,
#    1025,
#    1027,
#    1043,
#    1045,
#    1051,
#    1055,
#    1063,
#    1077,
#    1084,
#    1099,
#    1126,
#    1148,
#    1152,
#    1170,
#    1181,
#    1202,
#    1205,
# ...

# %%
idx3d.plot3dTree(show_points=True)
# Out:
# <div id="73fb1d14-4328-4545-a6c4-8d03ee88e77d" style="height: 860px; width: 1024px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("73fb1d14-4328-4545-a6c4-8d03ee88e77d", [{"z": [161210326.0, 244900852.0, null, 161210326.0, 161210326.0, null, 161210326.0, 161210326.0, null, 244900852.0, 244900852.0, null, 244900852.0, 244900852.0, null, 161210326.0, 244900852.0, null, 161210326.0, 161210326.0, null, 244900852.0, 244900852.0, null, 161210326.0, 244900852.0, null, 161210326.0, 161210326.0, null, 244900852.0, 244900852.0, null, 161210326.0, 244900852.0, null], "line": {"color": "#1f77b4", "width": 2}, "name": "0", "y": [35.6, 35.6, null, 35.6, 39.2, null, 35.6, 35.6, null, 35.6, 39.2, null, 35.6, 35.6, null, 39.2, 39.2, null, 39.2, 39.2, null, 39.2, 39.2, null, 35.6, 35.6, null, 35.6, 39.2, null, 35.6, 39.2, null, 39.2, 39.2, null], "x
# ...
